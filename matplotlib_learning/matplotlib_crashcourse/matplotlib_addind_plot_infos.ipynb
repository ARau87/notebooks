# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# Create test variables
x = [3,4,6,8]
y = [3,28,48,2]

# %%
# Plot the data
plt.plot(x, y)
plt.title('Info')
plt.xlabel('x_axis')
plt.ylabel('y_axis')
plt.show()
